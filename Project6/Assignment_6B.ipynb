# %% [markdown]
# <a href="https://colab.research.google.com/github/jagadeeshkn26/EVA2.0/blob/master/Project6/Assignment_6B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# summarize dataset shape
print('Train', train_features.shape, train_labels.shape)
print('Test', (test_features.shape, test_labels.shape))
# summarize pixel values
print('Train', train_features.min(), train_features.max(), train_features.mean(), train_features.std())
print('Test', test_features.min(), test_features.max(), test_features.mean(), test_features.std())
# Out:
# Train (50000, 32, 32, 3) (50000, 10)
# Test ((10000, 32, 32, 3), (10000, 10))
# Train 0.0 1.0 0.4733649 0.25156906
# Test 0.0 1.0 0.47658524 0.25121963

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.imshow(train_features[1])

# %% [markdown]
# #### Performing Image Normalization

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
from keras.callbacks import ModelCheckpoint

# %%
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler
def scheduler(epoch, lr):
  return round(0.003 * 1/(1 + 0.319 * epoch), 10)

# %%
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, SeparableConv2D
from keras.layers.merge import concatenate
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Activation, merge
from keras.layers.convolutional import Conv2D, MaxPooling2D, ZeroPadding2D, AveragePooling2D

# %%
input_shape = (32,32)+(3,)
img_input = Input(shape = input_shape)

# Normal Convolution 
x = Conv2D(32,3,strides=1,padding='same',data_format='channels_last',use_bias=False)(img_input)#(3*3,32*32) of the form (effective global receptive field,output channel size )
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)

# Spatially Seperable Convolutions if used should be used early in the network
x = Conv2D(32,kernel_size=(3,1),strides=1,padding = 'same',data_format='channels_last',use_bias=False)(x)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)
x = Conv2D(64,kernel_size=(1,3),strides=1,padding = 'same',data_format='channels_last',use_bias=False)(x) #(5*5,32*32)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)

# adding bottleneck layer i.e 1*1 convolutions followed by a max-pooling layer
x = Conv2D(32, 1,strides=1,data_format='channels_last',use_bias=False )(x) #(5*5,32*32)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2,2),data_format='channels_last')(x) #(10*10,16*16)
x = Dropout(0.1)(x)

# the following code till concatenate represents Grouped convolution using 3*3 and 5*5 Convolutions with 
# Depthwise Separable Convolution
x = SeparableConv2D(64,3,strides=1,padding='same',data_format='channels_last',use_bias=False)(x) #(12*12,16*16)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)

skip_tensor = x

x = Conv2D(128,3,strides=1,padding = 'same',data_format='channels_last',use_bias=False)(x) #(14*14,16*16)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)

x = concatenate([skip_tensor, x])

# Applying Bottleneck layer 
x = Conv2D(32,1,strides=1,data_format='channels_last',use_bias=False)(x) #(14*14,16*16)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2,2),data_format='channels_last')(x) #(28*28,8*8)
x = Dropout(0.1)(x)                
 
#  The following code block till concatenate represents Grouped Convolution (use 3x3 only, two with dilation = 1, and another with dilation = 2) 
x = Conv2D(32,3,strides=1,padding='same',data_format='channels_last',dilation_rate = 1,use_bias=False)(x) #(30*30,8*8)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)

x = Conv2D(32,3,strides=1,padding='same',data_format='channels_last',dilation_rate = 1,use_bias=False)(x) #(32*32,8*8)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)

skip_tensor = x
  
x = Conv2D(64,3,strides=1,padding='same',data_format='channels_last',dilation_rate = 2,use_bias=False)(x) #(36*36,8*8)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)  
x = Dropout(0.1)(x)

x = concatenate([skip_tensor, x])

x = Conv2D(10, 1,strides=1,data_format='channels_last',use_bias=False)(x) #(36*36,8*8)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)

# Normal convolution layer with higher kernel
x = Conv2D(num_classes,(8,8))(x) #(44*44,1*1)
x = Flatten()(x)
output = Activation('softmax')(x)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0619 03:47:51.347511 140568482379648 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0619 03:47:51.388390 140568482379648 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0619 03:47:51.396500 140568482379648 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0619 03:47:51.434213 140568482379648 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0619 03:47:51.435262 140568482379648 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0619 03:47:54.236340 140568482379648 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0619 03:47:54.327118 140568482379648 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0619 03:47:54.755077 140568482379648 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model = Model(inputs=img_input, outputs=output)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   3072        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 32)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   6144        dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   2048        dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 32)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 32)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 16, 16, 64)   2336        dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 64)   256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 64)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 128)  73728       dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 192)  0           dropout_5[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 32)   6144        concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 32)     0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 8, 8, 32)     0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 32)     9216        dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 32)     128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 8, 8, 32)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 8, 8, 32)     0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 32)     9216        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 32)     128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 32)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 8, 8, 32)     0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 64)     18432       dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 64)     256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 64)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 8, 8, 64)     0           activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 96)     0           dropout_9[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 10)     960         concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 10)     40          conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 10)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 8, 8, 10)     0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 1, 1, 10)     6410        dropout_11[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 10)           0           flatten_1[0][0]
# ==================================================================================================
# Total params: 140,658
# Trainable params: 139,614
# Non-trainable params: 1,044
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
# Out:
# W0619 03:48:10.969914 140568482379648 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler
def scheduler(epoch, lr):
  return round(0.003 * 1/(1 + 0.319 * epoch), 10)

# %%
# checkpoint
filepath="./Assignment6_19_2019-{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint,LearningRateScheduler(scheduler, verbose=1)]

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(featurewise_center=True,featurewise_std_normalization=True,data_format='channels_last')


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 50, 
                                 validation_data = (test_features, test_labels), verbose=1,callbacks = callbacks_list )
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=50)`
#   # This is added back by InteractiveShellApp.init_path()
# W0619 03:49:14.813415 140568482379648 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/50
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:716: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:724: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 00001: LearningRateScheduler setting learning rate to 0.003.
# 390/390 [==============================] - 40s 102ms/step - loss: 1.4645 - acc: 0.4656 - val_loss: 1.7121 - val_acc: 0.4725
#
# Epoch 00001: val_acc improved from -inf to 0.47250, saving model to ./Assignment6_19_2019-01-0.47.hdf5
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0022744503.
# 390/390 [==============================] - 35s 90ms/step - loss: 1.0531 - acc: 0.6204 - val_loss: 1.1135 - val_acc: 0.6025
#
# Epoch 00002: val_acc improved from 0.47250 to 0.60250, saving model to ./Assignment6_19_2019-02-0.60.hdf5
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0018315018.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.9017 - acc: 0.6771 - val_loss: 0.9648 - val_acc: 0.6664
#
# Epoch 00003: val_acc improved from 0.60250 to 0.66640, saving model to ./Assignment6_19_2019-03-0.67.hdf5
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0015329586.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.8051 - acc: 0.7157 - val_loss: 1.0073 - val_acc: 0.6611
#
# Epoch 00004: val_acc did not improve from 0.66640
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0013181019.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.7524 - acc: 0.7333 - val_loss: 0.8511 - val_acc: 0.7082
#
# Epoch 00005: val_acc improved from 0.66640 to 0.70820, saving model to ./Assignment6_19_2019-05-0.71.hdf5
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0011560694.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.7037 - acc: 0.7508 - val_loss: 0.7789 - val_acc: 0.7249
#
# Epoch 00006: val_acc improved from 0.70820 to 0.72490, saving model to ./Assignment6_19_2019-06-0.72.hdf5
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0010295127.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.6644 - acc: 0.7646 - val_loss: 0.8086 - val_acc: 0.7260
#
# Epoch 00007: val_acc improved from 0.72490 to 0.72600, saving model to ./Assignment6_19_2019-07-0.73.hdf5
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0009279307.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.6379 - acc: 0.7760 - val_loss: 0.7196 - val_acc: 0.7519
#
# Epoch 00008: val_acc improved from 0.72600 to 0.75190, saving model to ./Assignment6_19_2019-08-0.75.hdf5
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0008445946.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.6116 - acc: 0.7837 - val_loss: 0.6969 - val_acc: 0.7636
#
# Epoch 00009: val_acc improved from 0.75190 to 0.76360, saving model to ./Assignment6_19_2019-09-0.76.hdf5
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0007749935.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.5853 - acc: 0.7919 - val_loss: 0.6252 - val_acc: 0.7857
#
# Epoch 00010: val_acc improved from 0.76360 to 0.78570, saving model to ./Assignment6_19_2019-10-0.79.hdf5
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0007159905.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.5701 - acc: 0.7981 - val_loss: 0.6321 - val_acc: 0.7809
#
# Epoch 00011: val_acc did not improve from 0.78570
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.000665336.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.5569 - acc: 0.8051 - val_loss: 0.6180 - val_acc: 0.7860
#
# Epoch 00012: val_acc improved from 0.78570 to 0.78600, saving model to ./Assignment6_19_2019-12-0.79.hdf5
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0006213753.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.5428 - acc: 0.8094 - val_loss: 0.6212 - val_acc: 0.7898
#
# Epoch 00013: val_acc improved from 0.78600 to 0.78980, saving model to ./Assignment6_19_2019-13-0.79.hdf5
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0005828638.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.5316 - acc: 0.8142 - val_loss: 0.5985 - val_acc: 0.7931
#
# Epoch 00014: val_acc improved from 0.78980 to 0.79310, saving model to ./Assignment6_19_2019-14-0.79.hdf5
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0005488474.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.5233 - acc: 0.8145 - val_loss: 0.6008 - val_acc: 0.7971
#
# Epoch 00015: val_acc improved from 0.79310 to 0.79710, saving model to ./Assignment6_19_2019-15-0.80.hdf5
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0005185825.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.5085 - acc: 0.8216 - val_loss: 0.5851 - val_acc: 0.7984
#
# Epoch 00016: val_acc improved from 0.79710 to 0.79840, saving model to ./Assignment6_19_2019-16-0.80.hdf5
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.000491481.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4980 - acc: 0.8234 - val_loss: 0.5976 - val_acc: 0.7996
#
# Epoch 00017: val_acc improved from 0.79840 to 0.79960, saving model to ./Assignment6_19_2019-17-0.80.hdf5
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0004670715.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.4941 - acc: 0.8262 - val_loss: 0.5912 - val_acc: 0.8015
#
# Epoch 00018: val_acc improved from 0.79960 to 0.80150, saving model to ./Assignment6_19_2019-18-0.80.hdf5
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0004449718.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.4832 - acc: 0.8296 - val_loss: 0.5631 - val_acc: 0.8098
#
# Epoch 00019: val_acc improved from 0.80150 to 0.80980, saving model to ./Assignment6_19_2019-19-0.81.hdf5
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.000424869.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.4717 - acc: 0.8343 - val_loss: 0.5533 - val_acc: 0.8127
#
# Epoch 00020: val_acc improved from 0.80980 to 0.81270, saving model to ./Assignment6_19_2019-20-0.81.hdf5
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0004065041.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4727 - acc: 0.8319 - val_loss: 0.5481 - val_acc: 0.8154
#
# Epoch 00021: val_acc improved from 0.81270 to 0.81540, saving model to ./Assignment6_19_2019-21-0.82.hdf5
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.000389661.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.4655 - acc: 0.8350 - val_loss: 0.5799 - val_acc: 0.8055
#
# Epoch 00022: val_acc did not improve from 0.81540
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0003741581.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4574 - acc: 0.8381 - val_loss: 0.5735 - val_acc: 0.8056
#
# Epoch 00023: val_acc did not improve from 0.81540
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0003598417.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.4520 - acc: 0.8404 - val_loss: 0.5554 - val_acc: 0.8097
#
# Epoch 00024: val_acc did not improve from 0.81540
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0003465804.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4425 - acc: 0.8432 - val_loss: 0.5505 - val_acc: 0.8126
#
# Epoch 00025: val_acc did not improve from 0.81540
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0003342618.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.4427 - acc: 0.8433 - val_loss: 0.5378 - val_acc: 0.8185
#
# Epoch 00026: val_acc improved from 0.81540 to 0.81850, saving model to ./Assignment6_19_2019-26-0.82.hdf5
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0003227889.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.4391 - acc: 0.8456 - val_loss: 0.5430 - val_acc: 0.8149
#
# Epoch 00027: val_acc did not improve from 0.81850
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0003120774.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4307 - acc: 0.8468 - val_loss: 0.5394 - val_acc: 0.8198
#
# Epoch 00028: val_acc improved from 0.81850 to 0.81980, saving model to ./Assignment6_19_2019-28-0.82.hdf5
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.000302054.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4282 - acc: 0.8483 - val_loss: 0.5465 - val_acc: 0.8140
#
# Epoch 00029: val_acc did not improve from 0.81980
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0002926544.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4229 - acc: 0.8496 - val_loss: 0.5438 - val_acc: 0.8212
#
# Epoch 00030: val_acc improved from 0.81980 to 0.82120, saving model to ./Assignment6_19_2019-30-0.82.hdf5
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0002838221.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.4203 - acc: 0.8494 - val_loss: 0.5527 - val_acc: 0.8167
#
# Epoch 00031: val_acc did not improve from 0.82120
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0002755074.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4149 - acc: 0.8526 - val_loss: 0.5322 - val_acc: 0.8218
#
# Epoch 00032: val_acc improved from 0.82120 to 0.82180, saving model to ./Assignment6_19_2019-32-0.82.hdf5
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.000267666.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4142 - acc: 0.8531 - val_loss: 0.5347 - val_acc: 0.8200
#
# Epoch 00033: val_acc did not improve from 0.82180
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0002602585.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4105 - acc: 0.8548 - val_loss: 0.5192 - val_acc: 0.8266
#
# Epoch 00034: val_acc improved from 0.82180 to 0.82660, saving model to ./Assignment6_19_2019-34-0.83.hdf5
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.00025325.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4056 - acc: 0.8557 - val_loss: 0.5225 - val_acc: 0.8267
#
# Epoch 00035: val_acc improved from 0.82660 to 0.82670, saving model to ./Assignment6_19_2019-35-0.83.hdf5
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0002466091.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4038 - acc: 0.8580 - val_loss: 0.5444 - val_acc: 0.8204
#
# Epoch 00036: val_acc did not improve from 0.82670
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0002403076.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.4024 - acc: 0.8578 - val_loss: 0.5172 - val_acc: 0.8261
#
# Epoch 00037: val_acc did not improve from 0.82670
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0002343201.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3973 - acc: 0.8592 - val_loss: 0.5401 - val_acc: 0.8235
#
# Epoch 00038: val_acc did not improve from 0.82670
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0002286237.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3959 - acc: 0.8601 - val_loss: 0.5230 - val_acc: 0.8265
#
# Epoch 00039: val_acc did not improve from 0.82670
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0002231977.
# 390/390 [==============================] - 35s 90ms/step - loss: 0.3891 - acc: 0.8616 - val_loss: 0.5481 - val_acc: 0.8176
#
# Epoch 00040: val_acc did not improve from 0.82670
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0002180233.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3926 - acc: 0.8611 - val_loss: 0.5272 - val_acc: 0.8267
#
# Epoch 00041: val_acc did not improve from 0.82670
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.0002130833.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3918 - acc: 0.8618 - val_loss: 0.5134 - val_acc: 0.8310
#
# Epoch 00042: val_acc improved from 0.82670 to 0.83100, saving model to ./Assignment6_19_2019-42-0.83.hdf5
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.0002083623.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3833 - acc: 0.8642 - val_loss: 0.5208 - val_acc: 0.8307
#
# Epoch 00043: val_acc did not improve from 0.83100
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.0002038459.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3893 - acc: 0.8614 - val_loss: 0.5176 - val_acc: 0.8311
#
# Epoch 00044: val_acc improved from 0.83100 to 0.83110, saving model to ./Assignment6_19_2019-44-0.83.hdf5
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.0001995211.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3849 - acc: 0.8630 - val_loss: 0.5210 - val_acc: 0.8296
#
# Epoch 00045: val_acc did not improve from 0.83110
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.0001953761.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3766 - acc: 0.8662 - val_loss: 0.5238 - val_acc: 0.8260
#
# Epoch 00046: val_acc did not improve from 0.83110
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.0001913998.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3788 - acc: 0.8660 - val_loss: 0.5127 - val_acc: 0.8321
#
# Epoch 00047: val_acc improved from 0.83110 to 0.83210, saving model to ./Assignment6_19_2019-47-0.83.hdf5
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.0001875821.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3773 - acc: 0.8664 - val_loss: 0.5181 - val_acc: 0.8309
#
# Epoch 00048: val_acc did not improve from 0.83210
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.0001839137.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3738 - acc: 0.8680 - val_loss: 0.5193 - val_acc: 0.8293
#
# Epoch 00049: val_acc did not improve from 0.83210
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.000180386.
# 390/390 [==============================] - 35s 89ms/step - loss: 0.3723 - acc: 0.8686 - val_loss: 0.5173 - val_acc: 0.8277
#
# Epoch 00050: val_acc did not improve from 0.83210
# Model took 1757.04 seconds to train
# Accuracy on test data is: 82.77
